# %% [markdown]
# ###  functions are first-class objects
# First-class object is a program entity that can be:
# - created at runtime
# - assigned to a variable or element in a data structure
# - passed as an argument to a function
# - returned as the result of a function

# %%
def hello():
    print("hello")
    
print(type(hello))

a = hello
a()
# Out:
# <class 'function'>
# hello

# %% [markdown]
# ### functions can use recursion

# %%
def factorial(n):
    return 1 if n<2 else n * factorial(n-1)

factorial(77)
# Out:
# 145183092028285869634070784086308284983740379224208358846781574688061991349156420080065207861248000000000000000000

# %% [markdown]
# ### args name in functions can be used as `keyword`

# %%
def abc(a,b,c):
    for i in ('a','b','c'):
        print(i,"got",eval(i))

abc('to_a', 'to_b', 'to_c')
# Out:
# a got to_a
# b got to_b
# c got to_c

# %%
abc(b = 'to_b', c = 'to_c', a = 'to_a')
# Out:
# a got to_a
# b got to_b
# c got to_c

# %% [markdown]
# ###  if you want keyord-only arguments, put a `*` in the signature

# %%
def abc_keyword_only(*,a,b,c):
    for i in ('a','b','c'):
        print(i,"got",eval(i))

#abc_keyword_only('to_a', 'to_b', 'to_c') # error
abc_keyword_only(b = 'to_b', c = 'to_c', a = 'to_a')
# Out:
# a got to_a
# b got to_b
# c got to_c

# %% [markdown]
# ### default values

# %%
def abc_with_default(a='default_a',
                     b='default_b',
                     c='default_c'):
    abc(a,b,c)
    
abc_with_default(b = 'to_b')
# Out:
# a got default_a
# b got to_b
# c got default_c

# %% [markdown]
# ### documentation

# %%
def foo():
    '''
    string documenting foo(). 
    accessible via help(foo)
    '''
    pass

help(foo)
# Out:
# Help on function foo in module __main__:
#
# foo()
#     string documenting foo().
#     accessible via help(foo)

# %% [markdown]
# ### function annotations

# %%
def complicated_function(text:str, max_len:'int>0'=80) -> str:
    '''documentation for complicated_function'''
    pass

# %%
help(complicated_function)
# Out:
# Help on function complicated_function in module __main__:
#
# complicated_function(text: str, max_len: 'int>0' = 80) -> str
#     documentation for complicated_function

# %% [markdown]
# ###  much more

# %%
for i in dir(complicated_function):
    print(i,'is',eval('complicated_function.'+i))
# Out:
# __annotations__ is {'text': <class 'str'>, 'max_len': 'int>0', 'return': <class 'str'>}
# __call__ is <method-wrapper '__call__' of function object at 0x7f93a6f31510>
# __class__ is <class 'function'>
# __closure__ is None
# __code__ is <code object complicated_function at 0x7f93b406d780, file "<ipython-input-13-ab2ec88ee8c0>", line 1>
# __defaults__ is (80,)
# __delattr__ is <method-wrapper '__delattr__' of function object at 0x7f93a6f31510>
# __dict__ is {}
# __dir__ is <built-in method __dir__ of function object at 0x7f93a6f31510>
# __doc__ is documentation for complicated_function
# __eq__ is <method-wrapper '__eq__' of function object at 0x7f93a6f31510>
# __format__ is <built-in method __format__ of function object at 0x7f93a6f31510>
# __ge__ is <method-wrapper '__ge__' of function object at 0x7f93a6f31510>
# __get__ is <method-wrapper '__get__' of function object at 0x7f93a6f31510>
# __getattribute__ is <method-wrapper '__getattribute__' of function object at 0x7f93a6f31510>
# __globals__ is {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'def hello():\n    print("hello")\n    \nprint(type(hello))\n\na = hello\na()', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(77)', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(770)', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(7700)', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(1000)', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nlog(factorial(1000))', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(77)', 'def abc(a,b,c):\n    for i in (\'a\',\'b\',\'c\'):\n        print(i,"got",eval(i))\n\nabc(\'to_a\', \'to_b\', \'to_c\')', "abc(b = 'to_b', c = 'to_c', a = 'to_a')", 'def abc_keyword_only(*,a,b,c):\n    for i in (\'a\',\'b\',\'c\'):\n        print(i,"got",eval(i))\n\n#abc_keyword_only(\'to_a\', \'to_b\', \'to_c\') # error\nabc_keyword_only(b = \'to_b\', c = \'to_c\', a = \'to_a\')', "def abc_with_default(a='default_a',\n                     b='default_b',\n                     c='default_c'):\n    abc(a,b,c)\n    \nabc_with_default(b = 'to_b')", "def foo():\n    '''\n    string documenting foo(). \n    accessible via help(foo)\n    '''\n    pass\n\nhelp(foo)", "def complicated_function(text:str, max_len:'int>0'=80) -> str:\n    '''documentation for complicated_function'''\n    pass", 'help(complicated_function)', "for i in dir(complicated_function):\n    print(i,'is',eval('complicated_function.'+i))"], '_oh': {2: 145183092028285869634070784086308284983740379224208358846781574688061991349156420080065207861248000000000000000000, 3: ..., 5: ..., 7: 145183092028285869634070784086308284983740379224208358846781574688061991349156420080065207861248000000000000000000}, '_dh': ['/home/davide/1✪1✪3/DSSC/Corsi/AdvanceProgramming/advanced_programming-2018-19/lectures/python/02_variables_and_functions'], 'In': ['', 'def hello():\n    print("hello")\n    \nprint(type(hello))\n\na = hello\na()', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(77)', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(770)', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(7700)', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(1000)', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nlog(factorial(1000))', 'def factorial(n):\n    return 1 if n<2 else n * factorial(n-1)\n\nfactorial(77)', 'def abc(a,b,c):\n    for i in (\'a\',\'b\',\'c\'):\n        print(i,"got",eval(i))\n\nabc(\'to_a\', \'to_b\', \'to_c\')', "abc(b = 'to_b', c = 'to_c', a = 'to_a')", 'def abc_keyword_only(*,a,b,c):\n    for i in (\'a\',\'b\',\'c\'):\n        print(i,"got",eval(i))\n\n#abc_keyword_only(\'to_a\', \'to_b\', \'to_c\') # error\nabc_keyword_only(b = \'to_b\', c = \'to_c\', a = \'to_a\')', "def abc_with_default(a='default_a',\n                     b='default_b',\n                     c='default_c'):\n    abc(a,b,c)\n    \nabc_with_default(b = 'to_b')", "def foo():\n    '''\n    string documenting foo(). \n    accessible via help(foo)\n    '''\n    pass\n\nhelp(foo)", "def complicated_function(text:str, max_len:'int>0'=80) -> str:\n    '''documentation for complicated_function'''\n    pass", 'help(complicated_function)', "for i in dir(complicated_function):\n    print(i,'is',eval('complicated_function.'+i))"], 'Out': {2: 145183092028285869634070784086308284983740379224208358846781574688061991349156420080065207861248000000000000000000, 3: ..., 5: ..., 7: 145183092028285869634070784086308284983740379224208358846781574688061991349156420080065207861248000000000000000000}, 'get_ipython': <bound method Inte ...
# __gt__ is <method-wrapper '__gt__' of function object at 0x7f93a6f31510>
# __hash__ is <method-wrapper '__hash__' of function object at 0x7f93a6f31510>
# __init__ is <method-wrapper '__init__' of function object at 0x7f93a6f31510>
# __init_subclass__ is <built-in method __init_subclass__ of type object at 0x5622c8664120>
# __kwdefaults__ is None
# __le__ is <method-wrapper '__le__' of function object at 0x7f93a6f31510>
# __lt__ is <method-wrapper '__lt__' of function object at 0x7f93a6f31510>
# __module__ is __main__
# __name__ is complicated_function
# __ne__ is <method-wrapper '__ne__' of function object at 0x7f93a6f31510>
# __new__ is <built-in method __new__ of type object at 0x5622c8664120>
# __qualname__ is complicated_function
# __reduce__ is <built-in method __reduce__ of function object at 0x7f93a6f31510>
# __reduce_ex__ is <built-in method __reduce_ex__ of function object at 0x7f93a6f31510>
# __repr__ is <method-wrapper '__repr__' of function object at 0x7f93a6f31510>
# __setattr__ is <method-wrapper '__setattr__' of function object at 0x7f93a6f31510>
# __sizeof__ is <built-in method __sizeof__ of function object at 0x7f93a6f31510>
# __str__ is <method-wrapper '__str__' of function object at 0x7f93a6f31510>
# __subclasshook__ is <built-in method __subclasshook__ of type object at 0x5622c8664120>

# %%
eval("print('ciao')")
# Out:
# ciao
